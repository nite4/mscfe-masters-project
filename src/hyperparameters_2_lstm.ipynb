# %%
# %conda install -c conda-forge ta-lib -q
# %pip install -r requirements.txt -q

# import boto3
import data
import glob
import matplotlib.pyplot as plt
import models
import numpy as np
import os
import pandas as pd
import pypickle
import strategy
import time

from data import * 
from feature_engineering import FeaturesEngineering
from models import Models
from io import StringIO
from IPython.display import display
from sklearn.linear_model import LassoCV
from utils import log
# Out:
# 2025-02-24 21:16:37.220674: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-24 21:16:37.231044: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740402997.243242    7495 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740402997.246882    7495 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-24 21:16:37.259637: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
pypickle_overwrite = True

models = Models(use_xgboost_gpu=True)

# %%
dir_project = os.getcwd()
dir_models = os.path.join(dir_project, 'models')
dir_models_base = os.path.join(dir_project, 'models', 'base')
dir_models_scaler = os.path.join(dir_project, 'models', 'scaler')
dir_models_best = os.path.join(dir_project, 'models', 'best')

print(f"""
Project directory: {dir_project}
Models directory: {dir_models}
Base models directory: {dir_models_base}
Scalers directory: {dir_models_scaler}
Best models directory: {dir_models_best}
""")
# Out:
# Project directory: /home/alfred/projects/mscfe-masters-project/src
# Models directory: /home/alfred/projects/mscfe-masters-project/src/models
# Base models directory: /home/alfred/projects/mscfe-masters-project/src/models/base
# Scalers directory: /home/alfred/projects/mscfe-masters-project/src/models/scaler
# Best models directory: /home/alfred/projects/mscfe-masters-project/src/models/best

# %% [markdown]
# # Read raw data

# %%
# Define S3 bucket and file path
bucket_name = 'mscfe-capstone-project-bucket'
file_key = 'filtered_data.csv'

filtered = pd.read_csv('filtered_data.csv').drop(['Unnamed: 0'], axis=1)
display(filtered)
# Out:
#      seriesX    seriesY  correlation  spread_adf_stat  spread_adf_pValue  \
# 0       GOOG      GOOGL     0.999931        -4.971937           0.000025
# 1       META  DAXEX_ETF     0.888934        -2.917056           0.043400
# 2       AMZN    BNBUSDT     0.877059        -3.631203           0.005192
# 3       AMZN    TRXUSDT     0.814577        -3.869803           0.002269
# 4    SPY_ETF   AVAXUSDT     0.847292        -3.309927           0.014441
# 5    SPY_ETF    ETHUSDT     0.862483        -3.428205           0.010034
# 6   EQQQ_ETF    BNBUSDT     0.886060        -3.816404           0.002744
# 7    BNBUSDT    ADAUSDT     0.901459        -3.279504           0.015820
# 8    BNBUSDT    BTCUSDT     0.884604        -2.909961           0.044202
# 9    BNBUSDT    TRXUSDT     0.933562        -3.656380           0.004770
# 10   BNBUSDT    XRPUSDT     0.919004        -3.380878           0.011628
#
#     spread_stationary  series_coint_stat  series_coint_pValue  \
# 0                True          -4.976339             0.000182
# 1                True          -3.483091             0.033924
# 2                True          -3.545100             0.028601
# 3                True          -3.387413             0.043768
# 4                True          -3.698512             0.018406
# 5                True          -3.737367             0.016394
# 6                True          -3.670509             0.019987
# 7                True          -3.775562             0.014607
# 8                True          -3.393160             0.043116
# 9                True          -4.003675             0.007095
# 10               True          -4.054516             0.005995
#
#     series_cointegrated
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# 5                  True
# 6                  True
# 7                  True
# 8                  True
# 9                  True
# 10                 True

# %%
print('********************')
pairs = filtered['seriesX'].iloc[1:] + ' ' + filtered['seriesY'].iloc[1:]
print('Trading pairs:')
for p in pairs:
    print(p)
print('********************')

unique_tickers = pd.concat([filtered['seriesX'].iloc[1:], filtered['seriesY'].iloc[1:]]).drop_duplicates()
print('Unique tickers:')
for ut in unique_tickers:
    print(ut)
print('********************')

# Preview the source data
file_key = 'df_full.csv'
df_full = pd.read_csv('df_full.csv').drop(['Unnamed: 0'], axis=1)
# obj = s3.get_object(Bucket=bucket_name, Key=file_key)
# df_full = pd.read_csv(StringIO(obj['Body'].read().decode('utf-8'))).drop(['Unnamed: 0'], axis=1)
display(df_full.sample(5))
# Out:
# ********************
# Trading pairs:
# META DAXEX_ETF
# AMZN BNBUSDT
# AMZN TRXUSDT
# SPY_ETF AVAXUSDT
# SPY_ETF ETHUSDT
# EQQQ_ETF BNBUSDT
# BNBUSDT ADAUSDT
# BNBUSDT BTCUSDT
# BNBUSDT TRXUSDT
# BNBUSDT XRPUSDT
# ********************
# Unique tickers:
# META
# AMZN
# SPY_ETF
# EQQQ_ETF
# BNBUSDT
# DAXEX_ETF
# TRXUSDT
# AVAXUSDT
# ETHUSDT
# ADAUSDT
# BTCUSDT
# XRPUSDT
# ********************
#                    OpenTime         Open        High          Low  \
# 81718   2025-01-20 07:25:00   43086.0000   43086.000   43086.0000
# 392519  2025-01-20 15:45:00  103269.9600  103959.990  103261.6700
# 337565  2025-01-01 09:50:00       2.2521       2.263       2.2514
# 340088  2025-01-02 06:55:00     711.5500     712.040     711.1800
# 304071  2024-12-20 18:45:00    3486.6500    3489.640    3480.4900
#
#               Close    Symbol
# 81718    43086.0000  EQQQ_ETF
# 392519  103518.8100   BTCUSDT
# 337565       2.2599   XRPUSDT
# 340088     711.9000   BNBUSDT
# 304071    3485.9100   ETHUSDT

# %% [markdown]
# ## Placeholders

# %%
dict_data = {}
dict_cv_features = {}

# %% [markdown]
# # Features Engineering
#
# ## Create and normalizing features

# %%
# Initializing the FeaturesEngineering obj
feat = FeaturesEngineering()

# Default config
feat.default_config
# Out:
# {'ema': [8, 21, 55],
#  'macd': {'fast': 12, 'slow': 26, 'signal': 9},
#  'rsi': [14],
#  'bb': {'timeperiod': 20, 'nbdevup': 2, 'nbdevdn': 2},
#  'atr': {'timeperiod': 14},
#  'stoch': {'fastk_period': 14, 'slowk_period': 3, 'slowd_period': 3},
#  'cci': {'timeperiod': 20},
#  'willr': {'timeperiod': 14}}

# %% [markdown]
# 1. Create features from pairs data
# 2. Load saved scaler
# 3. Perform normalization / standardization

# %%
scaler_type = "StandardScaler"
dict_data['df_feat'] = {}
dict_data['df_norm'] = {}
dict_data['scaler'] = {}
i = 1

for p in pairs:

    print(f"({i}) Pairs: {p}")
    tickerX, tickerY = p.split(' ')
    
    # 1. Create features from pairs data
    df_feat = feat.create_features(
        tickerX, 
        tickerY,
        df_full[df_full['Symbol']==tickerX],
        df_full[df_full['Symbol']==tickerY],
        config=None, # using default config in the FeaturesEngineering
        dropna=True
    )

    # 2. Load saved scaler
    scaler_name = f"{scaler_type.lower()}_{p.replace(' ', '_')}.pkl"
    dir_scaler = os.path.join(dir_models_scaler, scaler_name)
    scaler = pypickle.load(dir_scaler)

    # 3. Perform normalization / standardization
    data_scaled = scaler.transform(df_feat)
    df_norm = pd.DataFrame(
        data_scaled, index=df_feat.index, columns=df_feat.columns
    )
    df_norm = df_norm.rename(columns={'Spread':'NormalizedSpread'})
    
    dict_data['df_feat'][p] = df_feat
    dict_data['df_norm'][p] = df_norm
    dict_data['scaler'][p] = scaler

    i+=1
    print('')
# Out:
# (1) Pairs: META DAXEX_ETF
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_META_DAXEX_ETF.pkl]
#
# (2) Pairs: AMZN BNBUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_AMZN_BNBUSDT.pkl]
#
# (3) Pairs: AMZN TRXUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_AMZN_TRXUSDT.pkl]
#
# (4) Pairs: SPY_ETF AVAXUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_SPY_ETF_AVAXUSDT.pkl]
#
# (5) Pairs: SPY_ETF ETHUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_SPY_ETF_ETHUSDT.pkl]
#
# (6) Pairs: EQQQ_ETF BNBUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_EQQQ_ETF_BNBUSDT.pkl]
#
# (7) Pairs: BNBUSDT ADAUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_BNBUSDT_ADAUSDT.pkl]
#
# (8) Pairs: BNBUSDT BTCUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_BNBUSDT_BTCUSDT.pkl]
#
# (9) Pairs: BNBUSDT TRXUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_BNBUSDT_TRXUSDT.pkl]
#
# (10) Pairs: BNBUSDT XRPUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_BNBUSDT_XRPUSDT.pkl]

# %%
df_norm
# Out:
#                      BNBUSDT_EMA8  BNBUSDT_EMA21  BNBUSDT_EMA55  BNBUSDT_MACD  \
# OpenTime
# 2024-10-04 20:30:00     -1.680235      -1.686912      -1.672894      0.015952
# 2024-10-04 20:35:00     -1.673138      -1.683431      -1.672055      0.133083
# 2024-10-04 20:40:00     -1.666828      -1.679943      -1.671119      0.234829
# 2024-10-04 20:45:00     -1.664293      -1.677744      -1.670599      0.276419
# 2024-10-04 20:50:00     -1.663113      -1.676068      -1.670224      0.293876
# ...                           ...            ...            ...           ...
# 2025-01-20 19:35:00      0.624619       0.608262       0.611732      0.485135
# 2025-01-20 19:40:00      0.630192       0.612101       0.613190      0.554318
# 2025-01-20 19:45:00      0.620045       0.609665       0.612264      0.387205
# 2025-01-20 19:50:00      0.610887       0.606931       0.611167      0.232844
# 2025-01-20 19:55:00      0.606652       0.605628       0.610575      0.151844
#
#                      BNBUSDT_RSI14  BNBUSDT_BBupper  BNBUSDT_BBmiddle  \
# OpenTime
# 2024-10-04 20:30:00       1.319364        -1.707088         -1.695708
# 2024-10-04 20:35:00       1.657784        -1.698144         -1.692503
# 2024-10-04 20:40:00       1.761771        -1.690607         -1.688853
# 2024-10-04 20:45:00       1.075843        -1.686307         -1.686271
# 2024-10-04 20:50:00       0.864854        -1.683056         -1.684223
# ...                            ...              ...               ...
# 2025-01-20 19:35:00       0.950306         0.604907          0.592423
# 2025-01-20 19:40:00       1.087021         0.601049          0.600597
# 2025-01-20 19:45:00      -0.515124         0.594588          0.603811
# 2025-01-20 19:50:00      -0.619930         0.589697          0.605948
# 2025-01-20 19:55:00      -0.316146         0.587507          0.607551
#
#                      BNBUSDT_BBlower  BNBUSDT_ATR14  BNBUSDT_StochK14  ...  \
# OpenTime                                                               ...
# 2024-10-04 20:30:00        -1.679849      -0.863332          1.416107  ...
# 2024-10-04 20:35:00        -1.682527      -0.831344          1.416107  ...
# 2024-10-04 20:40:00        -1.682866      -0.857953          1.416107  ...
# 2024-10-04 20:45:00        -1.682050      -0.826350          1.234789  ...
# 2024-10-04 20:50:00        -1.681239      -0.853316          0.993031  ...
# ...                              ...            ...               ...  ...
# 2025-01-20 19:35:00         0.578171      -0.169055          1.243066  ...
# 2025-01-20 19:40:00         0.598644      -0.216222          1.377433  ...
# 2025-01-20 19:45:00         0.611756       0.200332          0.418857  ...
# 2025-01-20 19:50:00         0.621084       0.116925         -0.578393  ...
# 2025-01-20 19:55:00         0.626566       0.097196         -1.392730  ...
#
#                      XRPUSDT_RSI14  XRPUSDT_BBupper  XRPUSDT_BBmiddle  \
# OpenTime
# 2024-10-04 20:30:00       0.353140        -1.137817         -1.135206
# 2024-10-04 20:35:00       0.616383        -1.137577         -1.135090
# 2024-10-04 20:40:00       0.616383        -1.137367         -1.134990
# 2024-10-04 20:45:00       0.016140        -1.137333         -1.134974
# 2024-10-04 20:50:00      -0.429623        -1.137368         -1.134996
# ...                            ...              ...               ...
# 2025-01-20 19:35:00       0.245891         1.758357          1.734044
# 2025-01-20 19:40:00       0.336222         1.748690          1.739917
# 2025-01-20 19:45:00      -1.111384         1.741011          1.741962
# 2025-01-20 19:50:00      -1.177519         1.740226          1.742216
# 2025-01-20 19:55:00      -0.803253         1.739258          1.742631
#
#                      XRPUSDT_BBlower  XRPUSDT_ATR14  XRPUSDT_StochK14  \
# OpenTime
# 2024-10-04 20:30:00        -1.132089      -0.883651          0.970838
# 2024-10-04 20:35:00        -1.132100      -0.884681          1.322502
# 2024-10-04 20:40:00        -1.132115      -0.892122          1.463168
# 2024-10-04 20:45:00        -1.132117      -0.887683          1.240081
# 2024-10-04 20:50:00        -1.132125      -0.885182          0.825776
# ...                              ...            ...               ...
# 2025-01-20 19:35:00         1.708411       1.144744          0.158005
# 2025-01-20 19:40:00         1.730243       1.034497          0.261611
# 2025-01-20 19:45:00         1.742272       1.640611         -0.208626
# 2025-01-20 19:50:00         1.743593       1.498187         -0.834629
# 2025-01-20 19:55:00         1.745426       1.481045         -1.409344
#
#                      XRPUSDT_StochD3  XRPUSDT_CCI20  XRPUSDT_WILLR14  \
# OpenTime
# 2024-10-04 20:30:00         0.240717       0.903191         1.344690
# 2024-10-04 20:35:00         0.896639       1.083912         1.344690
# 2024-10-04 20:40:00         1.297480       0.964370         1.344690
# 2024-10-04 20:45:00         1.390479       0.447084         0.729649
# 2024-10-04 20:50:00         1.218906       0.040351         0.202471
# ...                              ...            ...              ...
# 2025-01-20 19:35:00         0.212806       0.387378         0.258936
# 2025-01-20 19:40:00         0.200114       0.437498         0.633000
# 2025-01-20 19:45:00         0.072836      -1.391789        -1.466926
# 2025-01-20 19:50:00        -0.270026      -1.540820        -1.466926
# 2025-01-20 19:55:00        -0.847184      -1.192728        -0.951463
#
#                      NormalizedSpread
# OpenTime
# 2024-10-04 20:30:00         -1.665027
# 2024-10-04 20:35:00         -1.654194
# 2024-10-04 20:40:00         -1.650581
# 2024-10-04 20:45:00         -1.661408
# 2024-10-04 20:50:00         -1.665011
# ...                               ...
# 2025-01-20 19:35:00          0.623280
# 2025-01-20 19:40:00          0.630279
# 2025-01-20 19:45:00          0.564991
# 2025-01-20 19:50:00          0.559261
# 2025-01-20 19:55:00          0.572271
#
# [31051 rows x 27 columns]

# %% [markdown]
# ## Read LassoCV selected features

# %%
lasso_cv_name = f"lasso_cv_features.pkl"
dir_lasso = os.path.join(dir_models, lasso_cv_name)
dict_cv_features = pypickle.load(dir_lasso)

for key in dict_cv_features:
    print(f"{key}: {dict_cv_features[key]}")
# Out:
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/lasso_cv_features.pkl]
# META DAXEX_ETF: ['META_EMA8', 'META_EMA55', 'META_RSI14', 'META_ATR14', 'META_StochD3', 'META_CCI20', 'META_WILLR14', 'DAXEX_ETF_EMA8', 'DAXEX_ETF_EMA21', 'DAXEX_ETF_MACD', 'DAXEX_ETF_BBupper', 'DAXEX_ETF_BBmiddle', 'DAXEX_ETF_BBlower', 'DAXEX_ETF_StochD3']
# AMZN BNBUSDT: ['AMZN_EMA8', 'AMZN_EMA21', 'AMZN_EMA55', 'AMZN_RSI14', 'AMZN_ATR14', 'AMZN_StochD3', 'AMZN_WILLR14', 'BNBUSDT_EMA8', 'BNBUSDT_EMA55', 'BNBUSDT_MACD', 'BNBUSDT_RSI14', 'BNBUSDT_ATR14', 'BNBUSDT_StochD3', 'BNBUSDT_CCI20', 'BNBUSDT_WILLR14']
# AMZN TRXUSDT: ['AMZN_EMA8', 'AMZN_EMA55', 'AMZN_RSI14', 'AMZN_ATR14', 'AMZN_StochD3', 'AMZN_CCI20', 'AMZN_WILLR14', 'TRXUSDT_MACD']
# SPY_ETF AVAXUSDT: ['SPY_ETF_EMA8', 'SPY_ETF_EMA55', 'SPY_ETF_MACD', 'SPY_ETF_RSI14', 'SPY_ETF_BBupper', 'SPY_ETF_BBmiddle', 'SPY_ETF_BBlower', 'SPY_ETF_ATR14', 'SPY_ETF_StochK14', 'SPY_ETF_StochD3', 'SPY_ETF_CCI20', 'SPY_ETF_WILLR14', 'AVAXUSDT_EMA8', 'AVAXUSDT_EMA55', 'AVAXUSDT_MACD', 'AVAXUSDT_ATR14', 'AVAXUSDT_StochK14', 'AVAXUSDT_StochD3', 'AVAXUSDT_CCI20', 'AVAXUSDT_WILLR14']
# SPY_ETF ETHUSDT: ['SPY_ETF_EMA8', 'SPY_ETF_EMA21', 'SPY_ETF_MACD', 'SPY_ETF_BBupper', 'SPY_ETF_BBmiddle', 'SPY_ETF_BBlower', 'SPY_ETF_ATR14', 'SPY_ETF_CCI20', 'ETHUSDT_EMA8', 'ETHUSDT_EMA55', 'ETHUSDT_MACD', 'ETHUSDT_RSI14', 'ETHUSDT_ATR14', 'ETHUSDT_StochD3', 'ETHUSDT_CCI20']
# EQQQ_ETF BNBUSDT: ['EQQQ_ETF_EMA8', 'EQQQ_ETF_EMA55', 'EQQQ_ETF_RSI14', 'EQQQ_ETF_ATR14', 'EQQQ_ETF_StochD3', 'EQQQ_ETF_CCI20', 'EQQQ_ETF_WILLR14', 'BNBUSDT_EMA8', 'BNBUSDT_MACD', 'BNBUSDT_BBupper', 'BNBUSDT_BBmiddle', 'BNBUSDT_BBlower']
# BNBUSDT ADAUSDT: ['BNBUSDT_EMA8', 'BNBUSDT_MACD', 'BNBUSDT_RSI14', 'BNBUSDT_StochD3', 'BNBUSDT_CCI20', 'BNBUSDT_WILLR14', 'ADAUSDT_ATR14', 'ADAUSDT_WILLR14']
# BNBUSDT BTCUSDT: ['BNBUSDT_WILLR14', 'BTCUSDT_EMA8', 'BTCUSDT_EMA21', 'BTCUSDT_EMA55', 'BTCUSDT_RSI14', 'BTCUSDT_BBlower', 'BTCUSDT_CCI20', 'BTCUSDT_WILLR14']
# BNBUSDT TRXUSDT: ['BNBUSDT_EMA8', 'BNBUSDT_EMA55', 'BNBUSDT_MACD', 'BNBUSDT_RSI14', 'BNBUSDT_StochD3', 'BNBUSDT_CCI20', 'BNBUSDT_WILLR14', 'TRXUSDT_EMA8', 'TRXUSDT_MACD', 'TRXUSDT_CCI20', 'TRXUSDT_WILLR14']
# BNBUSDT XRPUSDT: ['BNBUSDT_EMA8', 'BNBUSDT_MACD', 'BNBUSDT_RSI14', 'BNBUSDT_ATR14', 'BNBUSDT_StochD3', 'BNBUSDT_CCI20', 'BNBUSDT_WILLR14', 'XRPUSDT_EMA21', 'XRPUSDT_BBupper', 'XRPUSDT_ATR14', 'XRPUSDT_WILLR14']

# %% [markdown]
# # Hyperparameters Tunning
#
# ## LSTM Regression

# %%
dir_best = os.path.join(dir_models_best, 'lstm')
param_grid = {
    'units': [64, 128, 256],
    'lookback': [10, 5, 15],  # Number of steps to lookback
    'dropout_rate': [0.25],  # Dropout rates
    'batch_size': [32, 64], # Number of data per batch
}

verbose = True
tuned_params = []
i = 1

for p in pairs:
    print(f"({i}) Pairs: {p}")

    # 1. Read normalized features
    df_norm = dict_data['df_norm'][p]
    
    # 2. Create X, y based on LassoCV
    lasso_features_cols = dict_cv_features[p]
    target_col = df_norm.columns.tolist()[-1]
    df_lasso = pd.concat([df_norm[lasso_features_cols], df_norm[target_col]], axis=1)

    # 3. Run Hyperparameters tunning
    start_time = time.perf_counter()
    best_model, best_params, best_mse, best_df_test = models.hyperparameter_tuning(
        df=df_lasso, p=p, model_func=models.rnn_regression, param_grid=param_grid, verbose=verbose)
    end_time = time.perf_counter()
    elapsed_time = end_time - start_time

    stats = {
        'pair':p, 
        'best_mse': best_mse,
        'data_points': len(df_lasso),
        'features': len(df_lasso.columns),
    }
    stats.update(best_params)
    tuned_params.append(stats)

    print(f"Best MSE: {best_mse:.6f}")
    print(f"units: {best_params['units']}, lookback: {best_params['lookback']}, dropout_rate: {best_params['dropout_rate']}, batch_size: {best_params['batch_size']}")
    print(f"Time taken: {elapsed_time:.6f} seconds")

    # 4. Save best model future use like testing and strategy
    model_name = f"best_lstm_{p.replace(' ', '_')}.pkl"
    dir_model_name = os.path.join(dir_best, model_name)
    pypickle.save(dir_model_name, best_model, overwrite=pypickle_overwrite)

    i+=1
    print('')

dir_param = os.path.join(dir_best, 'best_model_results.csv')
df_lstm = pd.DataFrame(tuned_params).set_index('pair')
df_lstm.to_csv(dir_param)
display(df_lstm)
# Out:
# (1) Pairs: META DAXEX_ETF
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# I0000 00:00:1740403033.451755    7495 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21964 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740403034.972148    7661 service.cc:148] XLA service 0x7bb4d4003160 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1740403034.972278    7661 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-02-24 21:17:15.005310: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1740403035.084404    7661 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1740403035.555359    7661 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# RNN MSE: 0.027271755008479427
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# RNN MSE: 0.02161120370885995
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step
# RNN MSE: 0.018882445406812567
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# RNN MSE: 0.030247614755980413
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# RNN MSE: 0.025447826142974982
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# RNN MSE: 0.024239270271585258
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# RNN MSE: 0.04136266586115297
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# RNN MSE: 0.022965042883137284
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
# RNN MSE: 0.022678354757584986
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# RNN MSE: 0.026677104195073516
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
# RNN MSE: 0.02590899090523147
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# RNN MSE: 0.02517186721198526
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# RNN MSE: 0.01967834128439755
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# RNN MSE: 0.02133611012046606
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# RNN MSE: 0.02135889386740326
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# RNN MSE: 0.021697122926791938
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# RNN MSE: 0.023968286216697395
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# RNN MSE: 0.021208609482915027
# Best parameters: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.018882445406812567
# Best MSE: 0.018882
# units: 64, lookback: 5, dropout_rate: 0.25, batch_size: 32
# Time taken: 101.793895 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_META_DAXEX_ETF.pkl]
#
# (2) Pairs: AMZN BNBUSDT
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.003440442394470801
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.003593357779734229
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0031435098694280587
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0033530668633654183
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# RNN MSE: 0.006149377161016429
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.0033148018432101116
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0034249371063657676
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.003338245056951312
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0030484425490953774
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.0036855148116397454
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.004670806077347539
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.004025904574221439
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0029464649470660924
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0038250992962047627
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0058971798446718375
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.0030014593664760138
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.004106659681116211
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0052800706723473015
# Best parameters: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.0029464649470660924
# Best MSE: 0.002946
# units: 256, lookback: 10, dropout_rate: 0.25, batch_size: 32
# Time taken: 288.551085 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_AMZN_BNBUSDT.pkl]
#
# (3) Pairs: AMZN TRXUSDT
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0017574649076407811
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.0017318610784373073
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# RNN MSE: 0.0019124173158252265
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.002163981769666243
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.002232109658067945
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.002771011664471928
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.002142281428023657
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.0019785709493395317
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# RNN MSE: 0.001931539539386707
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0015922386216900561
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.002972458607938975
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0026635705639704026
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0015801731167248082
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.00240797217341007
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# RNN MSE: 0.002691305603654407
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0017173437778600972
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# RNN MSE: 0.001328194588130599
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0016183979402689546
# Best parameters: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.001328194588130599
# Best MSE: 0.001328
# units: 256, lookback: 15, dropout_rate: 0.25, batch_size: 32
# Time taken: 271.246966 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_AMZN_TRXUSDT.pkl]
#
# (4) Pairs: SPY_ETF AVAXUSDT
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.03166534668662674
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.03470927424086113
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.02781852653572221
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.03448651719759465
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.028428754724635984
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.032140799702284346
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.028612144605941178
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# RNN MSE: 0.02999601893604688
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.029865538740940355
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# RNN MSE: 0.029980260671301308
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.03148862330624709
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.030848029698923335
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.025010069480309895
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.03191478197746989
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.026804206783177496
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.03605076774679231
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.041612060464386966
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.029545474636619128
# Best parameters: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.025010069480309895
# Best MSE: 0.025010
# units: 256, lookback: 10, dropout_rate: 0.25, batch_size: 32
# Time taken: 226.019012 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_SPY_ETF_AVAXUSDT.pkl]
#
# (5) Pairs: SPY_ETF ETHUSDT
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.003235186310745409
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0027984587369592018
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0025663817486192117
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0032723707682766395
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# RNN MSE: 0.0029495426617013568
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.002530904941799052
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0022573939115907216
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.004125193670057293
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0021533786090771876
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.003071321786403418
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0018998505518442925
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.002225906653717308
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.002141100899708206
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0020899487743574674
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.00505052825843388
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.0021752766812820116
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.002140114945186336
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.002848774784691327
# Best parameters: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.0018998505518442925
# Best MSE: 0.001900
# units: 128, lookback: 15, dropout_rate: 0.25, batch_size: 32
# Time taken: 192.560150 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_SPY_ETF_ETHUSDT.pkl]
#
# (6) Pairs: EQQQ_ETF BNBUSDT
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# RNN MSE: 0.005842477607929902
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# RNN MSE: 0.005156489986701005
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# RNN MSE: 0.004031736406950068
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# RNN MSE: 0.004716297550450408
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0040405694617920065
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.00573329598315044
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# RNN MSE: 0.0033014804801240736
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# RNN MSE: 0.004385416729305808
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# RNN MSE: 0.0052847853697966475
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# RNN MSE: 0.005247490336210565
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.005067087621378462
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.005861298732214271
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# RNN MSE: 0.0034900747208405423
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# RNN MSE: 0.004087630611768063
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# RNN MSE: 0.003526185639921333
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# RNN MSE: 0.003747733898955202
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0036159135488830355
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.003295682655570385
# Best parameters: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}, Best MSE: 0.003295682655570385
# Best MSE: 0.003296
# units: 256, lookback: 15, dropout_rate: 0.25, batch_size: 64
# Time taken: 159.171826 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_EQQQ_ETF_BNBUSDT.pkl]
#
# (7) Pairs: BNBUSDT ADAUSDT
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# RNN MSE: 0.0023126724089141326
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0006172067981645026
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0006109381029154611
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0007562104870439724
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.0005643285836033113
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0004278183542776838
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step
# RNN MSE: 0.0006437630599648191
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0008096763149693282
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.003282530967824594
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0005039568787854406
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.0017211062462221456
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.000683777799477369
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.024984133865560854
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step
# RNN MSE: 0.0048738344049770975
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.00044280643652096387
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.001408895236634474
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.0009484119182589333
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.000687742030777652
# Best parameters: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}, Best MSE: 0.0004278183542776838
# Best MSE: 0.000428
# units: 64, lookback: 15, dropout_rate: 0.25, batch_size: 64
# Time taken: 1047.100192 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_BNBUSDT_ADAUSDT.pkl]
#
# (8) Pairs: BNBUSDT BTCUSDT
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# RNN MSE: 0.0008873676138040756
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# RNN MSE: 0.0005549387563635811
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0004968020395568974
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.00041307888254291477
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.0003566007015615965
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.00039566862089032034
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# RNN MSE: 0.004926989336873176
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# RNN MSE: 0.00188916196424667
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0004268989871790415
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.00043106356800790826
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.00036480600333294494
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.0005241744238183755
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step
# RNN MSE: 0.0006119165124920695
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# RNN MSE: 0.0037472958796748853
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.00030465087925331816
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0007115959921958572
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0009702692880541656
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.000444230442511714
# Best parameters: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.00030465087925331816
# Best MSE: 0.000305
# units: 256, lookback: 5, dropout_rate: 0.25, batch_size: 32
# Time taken: 1196.908753 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_BNBUSDT_BTCUSDT.pkl]
#
# (9) Pairs: BNBUSDT TRXUSDT
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.000777954054169222
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# RNN MSE: 0.0022729755978918792
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0007740866269732223
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.00048764605653863245
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.0004620938586256961
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0004939842745713474
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# RNN MSE: 0.0009528932586932734
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# RNN MSE: 0.0012037057355247778
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0005529732316865045
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.000799628625547906
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.001419121718064726
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.000670297061897711
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# RNN MSE: 0.004603117875525573
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step
# RNN MSE: 0.00761578324970362
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.0034630012002668385
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0004907420497661332
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.0024483119598204314
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.002111845951614158
# Best parameters: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.0004620938586256961
# Best MSE: 0.000462
# units: 64, lookback: 15, dropout_rate: 0.25, batch_size: 32
# Time taken: 1321.906968 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_BNBUSDT_TRXUSDT.pkl]
#
# (10) Pairs: BNBUSDT XRPUSDT
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step
# RNN MSE: 0.0006759266607955525
# Testing params: {'units': 64, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# RNN MSE: 0.0004138091411967517
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0004672452000665092
# Testing params: {'units': 64, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0009064084034741847
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0013477001726928783
# Testing params: {'units': 64, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.001410603254049766
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# RNN MSE: 0.003525050052691553
# Testing params: {'units': 128, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# RNN MSE: 0.0014265889322082007
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0006229451586249449
# Testing params: {'units': 128, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0016463034316474513
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.00039299914264391913
# Testing params: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0007381103548564069
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# RNN MSE: 0.008968610539933737
# Testing params: {'units': 256, 'lookback': 10, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# RNN MSE: 0.0008684706224980754
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 32}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0065798857082236045
# Testing params: {'units': 256, 'lookback': 5, 'dropout_rate': 0.25, 'batch_size': 64}
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0010459699804915054
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0005963217980091682
# Testing params: {'units': 256, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 64}
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.0020739049179826223
# Best parameters: {'units': 128, 'lookback': 15, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.00039299914264391913
# Best MSE: 0.000393
# units: 128, lookback: 15, dropout_rate: 0.25, batch_size: 32
# Time taken: 1323.705713 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_BNBUSDT_XRPUSDT.pkl]
#                   best_mse  data_points  features  units  lookback  \
# pair
# META DAXEX_ETF    0.018882         1145        15     64         5
# AMZN BNBUSDT      0.002946         4991        16    256        10
# AMZN TRXUSDT      0.001328         4991         9    256        15
# SPY_ETF AVAXUSDT  0.025010         4997        21    256        10
# SPY_ETF ETHUSDT   0.001900         4997        16    128        15
# EQQQ_ETF BNBUSDT  0.003296         3217        13    256        15
# BNBUSDT ADAUSDT   0.000428        31051         9     64        15
# BNBUSDT BTCUSDT   0.000305        31051         9    256         5
# BNBUSDT TRXUSDT   0.000462        31051        12     64        15
# BNBUSDT XRPUSDT   0.000393        31051        12    128        15
#
#                   dropout_rate  batch_size
# pair
# META DAXEX_ETF            0.25          32
# AMZN BNBUSDT              0.25          32
# AMZN TRXUSDT              0.25          32
# SPY_ETF AVAXUSDT          0.25          32
# SPY_ETF ETHUSDT           0.25          32
# EQQQ_ETF BNBUSDT          0.25          64
# BNBUSDT ADAUSDT           0.25          64
# BNBUSDT BTCUSDT           0.25          32
# BNBUSDT TRXUSDT           0.25          32
# BNBUSDT XRPUSDT           0.25          32
