# %%
# %conda install -c conda-forge ta-lib -q
# %pip install -r requirements.txt -q

# import boto3
import data
import glob
import matplotlib.pyplot as plt
import models
import numpy as np
import os
import pandas as pd
import pypickle
import strategy
import time

from data import * 
from feature_engineering import FeaturesEngineering
from models import Models
from io import StringIO
from IPython.display import display
from sklearn.linear_model import LassoCV
from utils import log
# Out:
# 2025-03-01 18:16:28.806380: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-01 18:16:28.816226: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740824188.828226   45471 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740824188.831814   45471 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-01 18:16:28.844097: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
pypickle_overwrite = True

models = Models(use_xgboost_gpu=True)

# %%
dir_project = os.getcwd()
dir_models = os.path.join(dir_project, 'models')
dir_models_base = os.path.join(dir_project, 'models', 'base')
dir_models_scaler = os.path.join(dir_project, 'models', 'scaler')
dir_models_best = os.path.join(dir_project, 'models', 'best')

print(f"""
Project directory: {dir_project}
Models directory: {dir_models}
Base models directory: {dir_models_base}
Scalers directory: {dir_models_scaler}
Best models directory: {dir_models_best}
""")
# Out:
# Project directory: /home/alfred/projects/mscfe-masters-project/src
# Models directory: /home/alfred/projects/mscfe-masters-project/src/models
# Base models directory: /home/alfred/projects/mscfe-masters-project/src/models/base
# Scalers directory: /home/alfred/projects/mscfe-masters-project/src/models/scaler
# Best models directory: /home/alfred/projects/mscfe-masters-project/src/models/best

# %% [markdown]
# # Read raw data

# %%
# Define S3 bucket and file path
bucket_name = 'mscfe-capstone-project-bucket'
file_key = 'filtered_data.csv'

filtered = pd.read_csv('filtered_data.csv').drop(['Unnamed: 0'], axis=1)
display(filtered)
# Out:
#      seriesX    seriesY  correlation  spread_adf_stat  spread_adf_pValue  \
# 0       GOOG      GOOGL     0.999931        -4.971937           0.000025
# 1       META  DAXEX_ETF     0.888934        -2.917056           0.043400
# 2       AMZN    BNBUSDT     0.877059        -3.631203           0.005192
# 3       AMZN    TRXUSDT     0.814577        -3.869803           0.002269
# 4    SPY_ETF   AVAXUSDT     0.847292        -3.309927           0.014441
# 5    SPY_ETF    ETHUSDT     0.862483        -3.428205           0.010034
# 6   EQQQ_ETF    BNBUSDT     0.886060        -3.816404           0.002744
# 7    BNBUSDT    ADAUSDT     0.901459        -3.279504           0.015820
# 8    BNBUSDT    BTCUSDT     0.884604        -2.909961           0.044202
# 9    BNBUSDT    TRXUSDT     0.933562        -3.656380           0.004770
# 10   BNBUSDT    XRPUSDT     0.919004        -3.380878           0.011628
#
#     spread_stationary  series_coint_stat  series_coint_pValue  \
# 0                True          -4.976339             0.000182
# 1                True          -3.483091             0.033924
# 2                True          -3.545100             0.028601
# 3                True          -3.387413             0.043768
# 4                True          -3.698512             0.018406
# 5                True          -3.737367             0.016394
# 6                True          -3.670509             0.019987
# 7                True          -3.775562             0.014607
# 8                True          -3.393160             0.043116
# 9                True          -4.003675             0.007095
# 10               True          -4.054516             0.005995
#
#     series_cointegrated
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# 5                  True
# 6                  True
# 7                  True
# 8                  True
# 9                  True
# 10                 True

# %%
print('********************')
pairs = filtered['seriesX'].iloc[1:] + ' ' + filtered['seriesY'].iloc[1:]
print('Trading pairs:')
for p in pairs:
    print(p)
print('********************')

unique_tickers = pd.concat([filtered['seriesX'].iloc[1:], filtered['seriesY'].iloc[1:]]).drop_duplicates()
print('Unique tickers:')
for ut in unique_tickers:
    print(ut)
print('********************')

# Preview the source data
file_key = 'df_full.csv'
df_full = pd.read_csv('df_full.csv').drop(['Unnamed: 0'], axis=1)
# obj = s3.get_object(Bucket=bucket_name, Key=file_key)
# df_full = pd.read_csv(StringIO(obj['Body'].read().decode('utf-8'))).drop(['Unnamed: 0'], axis=1)
display(df_full.sample(5))
# Out:
# ********************
# Trading pairs:
# META DAXEX_ETF
# AMZN BNBUSDT
# AMZN TRXUSDT
# SPY_ETF AVAXUSDT
# SPY_ETF ETHUSDT
# EQQQ_ETF BNBUSDT
# BNBUSDT ADAUSDT
# BNBUSDT BTCUSDT
# BNBUSDT TRXUSDT
# BNBUSDT XRPUSDT
# ********************
# Unique tickers:
# META
# AMZN
# SPY_ETF
# EQQQ_ETF
# BNBUSDT
# DAXEX_ETF
# TRXUSDT
# AVAXUSDT
# ETHUSDT
# ADAUSDT
# BTCUSDT
# XRPUSDT
# ********************
#                    OpenTime         Open          High          Low  \
# 200184  2024-11-14 17:00:00      0.99960       0.99970      0.99960
# 391648  2025-01-20 08:30:00    691.11000     692.29000    690.84000
# 155446  2024-10-30 04:15:00      0.35280       0.35290      0.35190
# 280159  2024-12-12 11:30:00  99932.01000  100148.43000  99831.27000
# 105000  2024-10-12 15:50:00      0.11144       0.11146      0.11133
#
#               Close    Symbol
# 200184      0.99970  USDCUSDT
# 391648    691.13000   BNBUSDT
# 155446      0.35230   ADAUSDT
# 280159  99892.00000   BTCUSDT
# 105000      0.11143  DOGEUSDT

# %% [markdown]
# ## Placeholders

# %%
dict_data = {}
dict_cv_features = {}

# %% [markdown]
# # Features Engineering
#
# ## Create and normalizing features

# %%
# Initializing the FeaturesEngineering obj
feat = FeaturesEngineering()

# Default config
feat.default_config
# Out:
# {'ema': [8, 21, 55],
#  'macd': {'fast': 12, 'slow': 26, 'signal': 9},
#  'rsi': [14],
#  'bb': {'timeperiod': 20, 'nbdevup': 2, 'nbdevdn': 2},
#  'atr': {'timeperiod': 14},
#  'stoch': {'fastk_period': 14, 'slowk_period': 3, 'slowd_period': 3},
#  'cci': {'timeperiod': 20},
#  'willr': {'timeperiod': 14}}

# %% [markdown]
# 1. Create features from pairs data
# 2. Load saved scaler
# 3. Perform normalization / standardization

# %%
scaler_type = "StandardScaler"
dict_data['df_feat'] = {}
dict_data['df_norm'] = {}
dict_data['scaler'] = {}
i = 1

for p in pairs:

    print(f"({i}) Pairs: {p}")
    tickerX, tickerY = p.split(' ')
    
    # 1. Create features from pairs data
    df_feat = feat.create_features(
        tickerX, 
        tickerY,
        df_full[df_full['Symbol']==tickerX],
        df_full[df_full['Symbol']==tickerY],
        config=None, # using default config in the FeaturesEngineering
        dropna=True
    )

    # 2. Load saved scaler
    scaler_name = f"{scaler_type.lower()}_{p.replace(' ', '_')}.pkl"
    dir_scaler = os.path.join(dir_models_scaler, scaler_name)
    scaler = pypickle.load(dir_scaler)

    # 3. Perform normalization / standardization
    data_scaled = scaler.transform(df_feat)
    df_norm = pd.DataFrame(
        data_scaled, index=df_feat.index, columns=df_feat.columns
    )
    df_norm = df_norm.rename(columns={'Spread':'NormalizedSpread'})
    
    dict_data['df_feat'][p] = df_feat
    dict_data['df_norm'][p] = df_norm
    dict_data['scaler'][p] = scaler

    i+=1
    print('')
# Out:
# (1) Pairs: META DAXEX_ETF
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_META_DAXEX_ETF.pkl]
#
# (2) Pairs: AMZN BNBUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_AMZN_BNBUSDT.pkl]
#
# (3) Pairs: AMZN TRXUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_AMZN_TRXUSDT.pkl]
#
# (4) Pairs: SPY_ETF AVAXUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_SPY_ETF_AVAXUSDT.pkl]
#
# (5) Pairs: SPY_ETF ETHUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_SPY_ETF_ETHUSDT.pkl]
#
# (6) Pairs: EQQQ_ETF BNBUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_EQQQ_ETF_BNBUSDT.pkl]
#
# (7) Pairs: BNBUSDT ADAUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_BNBUSDT_ADAUSDT.pkl]
#
# (8) Pairs: BNBUSDT BTCUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_BNBUSDT_BTCUSDT.pkl]
#
# (9) Pairs: BNBUSDT TRXUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_BNBUSDT_TRXUSDT.pkl]
#
# (10) Pairs: BNBUSDT XRPUSDT
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/scaler/standardscaler_BNBUSDT_XRPUSDT.pkl]

# %%
df_norm
# Out:
#                      BNBUSDT_EMA8  BNBUSDT_EMA21  BNBUSDT_EMA55  BNBUSDT_MACD  \
# OpenTime
# 2024-10-04 20:30:00     -1.680235      -1.686912      -1.672894      0.015952
# 2024-10-04 20:35:00     -1.673138      -1.683431      -1.672055      0.133083
# 2024-10-04 20:40:00     -1.666828      -1.679943      -1.671119      0.234829
# 2024-10-04 20:45:00     -1.664293      -1.677744      -1.670599      0.276419
# 2024-10-04 20:50:00     -1.663113      -1.676068      -1.670224      0.293876
# ...                           ...            ...            ...           ...
# 2025-01-20 19:35:00      0.624619       0.608262       0.611732      0.485135
# 2025-01-20 19:40:00      0.630192       0.612101       0.613190      0.554318
# 2025-01-20 19:45:00      0.620045       0.609665       0.612264      0.387205
# 2025-01-20 19:50:00      0.610887       0.606931       0.611167      0.232844
# 2025-01-20 19:55:00      0.606652       0.605628       0.610575      0.151844
#
#                      BNBUSDT_RSI14  BNBUSDT_BBupper  BNBUSDT_BBmiddle  \
# OpenTime
# 2024-10-04 20:30:00       1.319364        -1.707088         -1.695708
# 2024-10-04 20:35:00       1.657784        -1.698144         -1.692503
# 2024-10-04 20:40:00       1.761771        -1.690607         -1.688853
# 2024-10-04 20:45:00       1.075843        -1.686307         -1.686271
# 2024-10-04 20:50:00       0.864854        -1.683056         -1.684223
# ...                            ...              ...               ...
# 2025-01-20 19:35:00       0.950306         0.604907          0.592423
# 2025-01-20 19:40:00       1.087021         0.601049          0.600597
# 2025-01-20 19:45:00      -0.515124         0.594588          0.603811
# 2025-01-20 19:50:00      -0.619930         0.589697          0.605948
# 2025-01-20 19:55:00      -0.316146         0.587507          0.607551
#
#                      BNBUSDT_BBlower  BNBUSDT_ATR14  BNBUSDT_StochK14  ...  \
# OpenTime                                                               ...
# 2024-10-04 20:30:00        -1.679849      -0.863332          1.416107  ...
# 2024-10-04 20:35:00        -1.682527      -0.831344          1.416107  ...
# 2024-10-04 20:40:00        -1.682866      -0.857953          1.416107  ...
# 2024-10-04 20:45:00        -1.682050      -0.826350          1.234789  ...
# 2024-10-04 20:50:00        -1.681239      -0.853316          0.993031  ...
# ...                              ...            ...               ...  ...
# 2025-01-20 19:35:00         0.578171      -0.169055          1.243066  ...
# 2025-01-20 19:40:00         0.598644      -0.216222          1.377433  ...
# 2025-01-20 19:45:00         0.611756       0.200332          0.418857  ...
# 2025-01-20 19:50:00         0.621084       0.116925         -0.578393  ...
# 2025-01-20 19:55:00         0.626566       0.097196         -1.392730  ...
#
#                      XRPUSDT_RSI14  XRPUSDT_BBupper  XRPUSDT_BBmiddle  \
# OpenTime
# 2024-10-04 20:30:00       0.353140        -1.137817         -1.135206
# 2024-10-04 20:35:00       0.616383        -1.137577         -1.135090
# 2024-10-04 20:40:00       0.616383        -1.137367         -1.134990
# 2024-10-04 20:45:00       0.016140        -1.137333         -1.134974
# 2024-10-04 20:50:00      -0.429623        -1.137368         -1.134996
# ...                            ...              ...               ...
# 2025-01-20 19:35:00       0.245891         1.758357          1.734044
# 2025-01-20 19:40:00       0.336222         1.748690          1.739917
# 2025-01-20 19:45:00      -1.111384         1.741011          1.741962
# 2025-01-20 19:50:00      -1.177519         1.740226          1.742216
# 2025-01-20 19:55:00      -0.803253         1.739258          1.742631
#
#                      XRPUSDT_BBlower  XRPUSDT_ATR14  XRPUSDT_StochK14  \
# OpenTime
# 2024-10-04 20:30:00        -1.132089      -0.883651          0.970838
# 2024-10-04 20:35:00        -1.132100      -0.884681          1.322502
# 2024-10-04 20:40:00        -1.132115      -0.892122          1.463168
# 2024-10-04 20:45:00        -1.132117      -0.887683          1.240081
# 2024-10-04 20:50:00        -1.132125      -0.885182          0.825776
# ...                              ...            ...               ...
# 2025-01-20 19:35:00         1.708411       1.144744          0.158005
# 2025-01-20 19:40:00         1.730243       1.034497          0.261611
# 2025-01-20 19:45:00         1.742272       1.640611         -0.208626
# 2025-01-20 19:50:00         1.743593       1.498187         -0.834629
# 2025-01-20 19:55:00         1.745426       1.481045         -1.409344
#
#                      XRPUSDT_StochD3  XRPUSDT_CCI20  XRPUSDT_WILLR14  \
# OpenTime
# 2024-10-04 20:30:00         0.240717       0.903191         1.344690
# 2024-10-04 20:35:00         0.896639       1.083912         1.344690
# 2024-10-04 20:40:00         1.297480       0.964370         1.344690
# 2024-10-04 20:45:00         1.390479       0.447084         0.729649
# 2024-10-04 20:50:00         1.218906       0.040351         0.202471
# ...                              ...            ...              ...
# 2025-01-20 19:35:00         0.212806       0.387378         0.258936
# 2025-01-20 19:40:00         0.200114       0.437498         0.633000
# 2025-01-20 19:45:00         0.072836      -1.391789        -1.466926
# 2025-01-20 19:50:00        -0.270026      -1.540820        -1.466926
# 2025-01-20 19:55:00        -0.847184      -1.192728        -0.951463
#
#                      NormalizedSpread
# OpenTime
# 2024-10-04 20:30:00         -1.665027
# 2024-10-04 20:35:00         -1.654194
# 2024-10-04 20:40:00         -1.650581
# 2024-10-04 20:45:00         -1.661408
# 2024-10-04 20:50:00         -1.665011
# ...                               ...
# 2025-01-20 19:35:00          0.623280
# 2025-01-20 19:40:00          0.630279
# 2025-01-20 19:45:00          0.564991
# 2025-01-20 19:50:00          0.559261
# 2025-01-20 19:55:00          0.572271
#
# [31051 rows x 27 columns]

# %% [markdown]
# ## Read LassoCV selected features

# %%
lasso_cv_name = f"lasso_cv_features.pkl"
dir_lasso = os.path.join(dir_models, lasso_cv_name)
dict_cv_features = pypickle.load(dir_lasso)

for key in dict_cv_features:
    print(f"{key}: {dict_cv_features[key]}")
# Out:
# [pypickle] Pickle file loaded: [/home/alfred/projects/mscfe-masters-project/src/models/lasso_cv_features.pkl]
# META DAXEX_ETF: ['META_EMA8', 'META_EMA55', 'META_RSI14', 'META_ATR14', 'META_StochD3', 'META_CCI20', 'META_WILLR14', 'DAXEX_ETF_EMA8', 'DAXEX_ETF_EMA21', 'DAXEX_ETF_MACD', 'DAXEX_ETF_BBupper', 'DAXEX_ETF_BBmiddle', 'DAXEX_ETF_BBlower', 'DAXEX_ETF_StochD3']
# AMZN BNBUSDT: ['AMZN_EMA8', 'AMZN_EMA21', 'AMZN_EMA55', 'AMZN_RSI14', 'AMZN_ATR14', 'AMZN_StochD3', 'AMZN_WILLR14', 'BNBUSDT_EMA8', 'BNBUSDT_EMA55', 'BNBUSDT_MACD', 'BNBUSDT_RSI14', 'BNBUSDT_ATR14', 'BNBUSDT_StochD3', 'BNBUSDT_CCI20', 'BNBUSDT_WILLR14']
# AMZN TRXUSDT: ['AMZN_EMA8', 'AMZN_EMA55', 'AMZN_RSI14', 'AMZN_ATR14', 'AMZN_StochD3', 'AMZN_CCI20', 'AMZN_WILLR14', 'TRXUSDT_MACD']
# SPY_ETF AVAXUSDT: ['SPY_ETF_EMA8', 'SPY_ETF_EMA55', 'SPY_ETF_MACD', 'SPY_ETF_RSI14', 'SPY_ETF_BBupper', 'SPY_ETF_BBmiddle', 'SPY_ETF_BBlower', 'SPY_ETF_ATR14', 'SPY_ETF_StochK14', 'SPY_ETF_StochD3', 'SPY_ETF_CCI20', 'SPY_ETF_WILLR14', 'AVAXUSDT_EMA8', 'AVAXUSDT_EMA55', 'AVAXUSDT_MACD', 'AVAXUSDT_ATR14', 'AVAXUSDT_StochK14', 'AVAXUSDT_StochD3', 'AVAXUSDT_CCI20', 'AVAXUSDT_WILLR14']
# SPY_ETF ETHUSDT: ['SPY_ETF_EMA8', 'SPY_ETF_EMA21', 'SPY_ETF_MACD', 'SPY_ETF_BBupper', 'SPY_ETF_BBmiddle', 'SPY_ETF_BBlower', 'SPY_ETF_ATR14', 'SPY_ETF_CCI20', 'ETHUSDT_EMA8', 'ETHUSDT_EMA55', 'ETHUSDT_MACD', 'ETHUSDT_RSI14', 'ETHUSDT_ATR14', 'ETHUSDT_StochD3', 'ETHUSDT_CCI20']
# EQQQ_ETF BNBUSDT: ['EQQQ_ETF_EMA8', 'EQQQ_ETF_EMA55', 'EQQQ_ETF_RSI14', 'EQQQ_ETF_ATR14', 'EQQQ_ETF_StochD3', 'EQQQ_ETF_CCI20', 'EQQQ_ETF_WILLR14', 'BNBUSDT_EMA8', 'BNBUSDT_MACD', 'BNBUSDT_BBupper', 'BNBUSDT_BBmiddle', 'BNBUSDT_BBlower']
# BNBUSDT ADAUSDT: ['BNBUSDT_EMA8', 'BNBUSDT_MACD', 'BNBUSDT_RSI14', 'BNBUSDT_StochD3', 'BNBUSDT_CCI20', 'BNBUSDT_WILLR14', 'ADAUSDT_ATR14', 'ADAUSDT_WILLR14']
# BNBUSDT BTCUSDT: ['BNBUSDT_WILLR14', 'BTCUSDT_EMA8', 'BTCUSDT_EMA21', 'BTCUSDT_EMA55', 'BTCUSDT_RSI14', 'BTCUSDT_BBlower', 'BTCUSDT_CCI20', 'BTCUSDT_WILLR14']
# BNBUSDT TRXUSDT: ['BNBUSDT_EMA8', 'BNBUSDT_EMA55', 'BNBUSDT_MACD', 'BNBUSDT_RSI14', 'BNBUSDT_StochD3', 'BNBUSDT_CCI20', 'BNBUSDT_WILLR14', 'TRXUSDT_EMA8', 'TRXUSDT_MACD', 'TRXUSDT_CCI20', 'TRXUSDT_WILLR14']
# BNBUSDT XRPUSDT: ['BNBUSDT_EMA8', 'BNBUSDT_MACD', 'BNBUSDT_RSI14', 'BNBUSDT_ATR14', 'BNBUSDT_StochD3', 'BNBUSDT_CCI20', 'BNBUSDT_WILLR14', 'XRPUSDT_EMA21', 'XRPUSDT_BBupper', 'XRPUSDT_ATR14', 'XRPUSDT_WILLR14']

# %% [markdown]
# # Hyperparameters Tunning
#
# ## LSTM Regression

# %%
dir_best = os.path.join(dir_models_best, 'lstm')
param_grid = {
    'units': [64, 128, 256],
    'dropout_rate': [0.25],  # Dropout rates
    'batch_size': [32, 64], # Number of data per batch
}

verbose = True
tuned_params = []
i = 1

for p in pairs:
    print(f"({i}) Pairs: {p}")

    # 1. Read normalized features
    df_norm = dict_data['df_norm'][p]
    
    # 2. Create X, y based on LassoCV
    lasso_features_cols = dict_cv_features[p]
    target_col = df_norm.columns.tolist()[-1]
    df_lasso = pd.concat([df_norm[lasso_features_cols], df_norm[target_col]], axis=1)

    # 3. Run Hyperparameters tunning
    start_time = time.perf_counter()
    best_model, best_params, best_mse, best_df_test = models.hyperparameter_tuning(
        df=df_lasso, p=p, model_func=models.rnn_regression, param_grid=param_grid, verbose=verbose)
    end_time = time.perf_counter()
    elapsed_time = end_time - start_time

    stats = {
        'pair':p, 
        'best_mse': best_mse,
        'data_points': len(df_lasso),
        'features': len(df_lasso.columns),
    }
    stats.update(best_params)
    tuned_params.append(stats)

    print(f"Best MSE: {best_mse:.6f}")
    print(f"units: {best_params['units']}, dropout_rate: {best_params['dropout_rate']}, batch_size: {best_params['batch_size']}")
    print(f"Time taken: {elapsed_time:.6f} seconds")

    # 4. Save best model future use like testing and strategy
    model_name = f"best_lstm_{p.replace(' ', '_')}.pkl"
    dir_model_name = os.path.join(dir_best, model_name)
    pypickle.save(dir_model_name, best_model, overwrite=pypickle_overwrite)

    i+=1
    print('')

dir_param = os.path.join(dir_best, 'best_model_results.csv')
df_lstm = pd.DataFrame(tuned_params).set_index('pair')
df_lstm.to_csv(dir_param)
display(df_lstm)
# Out:
# (1) Pairs: META DAXEX_ETF
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# I0000 00:00:1740824248.214191   45471 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 948 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740824249.371643   63977 service.cc:148] XLA service 0x74109c017cc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1740824249.371672   63977 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-03-01 18:17:29.392147: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1740824249.460704   63977 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1740824249.920751   63977 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# RNN MSE: 0.020920161911053482
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# RNN MSE: 0.02141693247757176
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# RNN MSE: 0.03091235073231842
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# RNN MSE: 0.024373067483238958
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# RNN MSE: 0.022594781522019367
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# RNN MSE: 0.02532144570585064
# Best parameters: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.020920161911053482
# Best MSE: 0.020920
# units: 64, dropout_rate: 0.25, batch_size: 32
# Time taken: 32.148889 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_META_DAXEX_ETF.pkl]
#
# (2) Pairs: AMZN BNBUSDT
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.003784068255701534
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.003662499771432331
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# RNN MSE: 0.0038307396208753274
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.0035474225507765435
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.00621466759238461
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.004416073090384573
# Best parameters: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 64}, Best MSE: 0.0035474225507765435
# Best MSE: 0.003547
# units: 128, dropout_rate: 0.25, batch_size: 64
# Time taken: 73.832542 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_AMZN_BNBUSDT.pkl]
#
# (3) Pairs: AMZN TRXUSDT
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0016693447265464733
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0022888257643921056
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# RNN MSE: 0.002108352438481833
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.0020870517056692474
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.0019845028908891337
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.001969048687654382
# Best parameters: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.0016693447265464733
# Best MSE: 0.001669
# units: 64, dropout_rate: 0.25, batch_size: 32
# Time taken: 73.309846 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_AMZN_TRXUSDT.pkl]
#
# (4) Pairs: SPY_ETF AVAXUSDT
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.033616004891826944
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.03513970877808958
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.03958254695598705
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RNN MSE: 0.03497027806611581
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.024208210384744987
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.025742412994369763
# Best parameters: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.024208210384744987
# Best MSE: 0.024208
# units: 256, dropout_rate: 0.25, batch_size: 32
# Time taken: 76.414850 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_SPY_ETF_AVAXUSDT.pkl]
#
# (5) Pairs: SPY_ETF ETHUSDT
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.002314454743058743
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0026726784878941564
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.002213094182793664
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0022333969822204026
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RNN MSE: 0.002119828077434058
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RNN MSE: 0.0022786146273029427
# Best parameters: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.002119828077434058
# Best MSE: 0.002120
# units: 256, dropout_rate: 0.25, batch_size: 32
# Time taken: 75.608343 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_SPY_ETF_ETHUSDT.pkl]
#
# (6) Pairs: EQQQ_ETF BNBUSDT
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# RNN MSE: 0.006300865956098129
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# RNN MSE: 0.0045765103568930045
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# RNN MSE: 0.014237489422216589
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# RNN MSE: 0.00474895012817485
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# RNN MSE: 0.0041183202336311795
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# RNN MSE: 0.0037025754776362496
# Best parameters: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 64}, Best MSE: 0.0037025754776362496
# Best MSE: 0.003703
# units: 256, dropout_rate: 0.25, batch_size: 64
# Time taken: 55.128989 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_EQQQ_ETF_BNBUSDT.pkl]
#
# (7) Pairs: BNBUSDT ADAUSDT
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step
# RNN MSE: 0.0004114681685435572
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step
# RNN MSE: 0.0004944614016294593
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# RNN MSE: 0.0011950724389865148
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# RNN MSE: 0.008249238847218088
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0007519877298144672
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# RNN MSE: 0.0005296648974039575
# Best parameters: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.0004114681685435572
# Best MSE: 0.000411
# units: 64, dropout_rate: 0.25, batch_size: 32
# Time taken: 425.736204 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_BNBUSDT_ADAUSDT.pkl]
#
# (8) Pairs: BNBUSDT BTCUSDT
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0004637482659422075
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.001120428610395059
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.0014609983146818952
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.00046431498604547467
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.006776509809344084
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# RNN MSE: 0.000911711164215129
# Best parameters: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.0004637482659422075
# Best MSE: 0.000464
# units: 64, dropout_rate: 0.25, batch_size: 32
# Time taken: 439.920383 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_BNBUSDT_BTCUSDT.pkl]
#
# (9) Pairs: BNBUSDT TRXUSDT
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0004045832144412739
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.001763406370754573
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.000819770410679857
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0005292064348092795
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RNN MSE: 0.005330082635984623
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step
# RNN MSE: 0.0004217711291085075
# Best parameters: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}, Best MSE: 0.0004045832144412739
# Best MSE: 0.000405
# units: 64, dropout_rate: 0.25, batch_size: 32
# Time taken: 505.585326 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_BNBUSDT_TRXUSDT.pkl]
#
# (10) Pairs: BNBUSDT XRPUSDT
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# RNN MSE: 0.0038878284544367164
# Testing params: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0003981785253816214
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RNN MSE: 0.0007197017372214292
# Testing params: {'units': 128, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RNN MSE: 0.000441272753380248
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 32}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step
# RNN MSE: 0.022614571622005152
# Testing params: {'units': 256, 'dropout_rate': 0.25, 'batch_size': 64}
# Training/Validation Phase
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# RNN MSE: 0.0017385370725580432
# Best parameters: {'units': 64, 'dropout_rate': 0.25, 'batch_size': 64}, Best MSE: 0.0003981785253816214
# Best MSE: 0.000398
# units: 64, dropout_rate: 0.25, batch_size: 64
# Time taken: 525.155400 seconds
# [pypickle] Pickle file saved: [/home/alfred/projects/mscfe-masters-project/src/models/best/lstm/best_lstm_BNBUSDT_XRPUSDT.pkl]
#                   best_mse  data_points  features  units  dropout_rate  \
# pair
# META DAXEX_ETF    0.020920         1145        15     64          0.25
# AMZN BNBUSDT      0.003547         4991        16    128          0.25
# AMZN TRXUSDT      0.001669         4991         9     64          0.25
# SPY_ETF AVAXUSDT  0.024208         4997        21    256          0.25
# SPY_ETF ETHUSDT   0.002120         4997        16    256          0.25
# EQQQ_ETF BNBUSDT  0.003703         3217        13    256          0.25
# BNBUSDT ADAUSDT   0.000411        31051         9     64          0.25
# BNBUSDT BTCUSDT   0.000464        31051         9     64          0.25
# BNBUSDT TRXUSDT   0.000405        31051        12     64          0.25
# BNBUSDT XRPUSDT   0.000398        31051        12     64          0.25
#
#                   batch_size
# pair
# META DAXEX_ETF            32
# AMZN BNBUSDT              64
# AMZN TRXUSDT              32
# SPY_ETF AVAXUSDT          32
# SPY_ETF ETHUSDT           32
# EQQQ_ETF BNBUSDT          64
# BNBUSDT ADAUSDT           32
# BNBUSDT BTCUSDT           32
# BNBUSDT TRXUSDT           32
# BNBUSDT XRPUSDT           64
